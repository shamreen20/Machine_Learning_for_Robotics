# %% [markdown]
# # Install packages

# %%
# !pip install swig mediapy
# !pip install mujoco==3.1.4
# !pip install torch torchrl
# !pip install gymnasium[box2d,mujoco]==0.28.1
# Out:
# Collecting swig
#   Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl.metadata (3.5 kB)
# Collecting mediapy
#   Downloading mediapy-1.2.4-py3-none-any.whl.metadata (4.8 kB)
# Requirement already satisfied: ipython in /usr/local/lib/python3.11/dist-packages (from mediapy) (7.34.0)
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.11/dist-packages (from mediapy) (3.10.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mediapy) (2.0.2)
# Requirement already satisfied: Pillow in /usr/local/lib/python3.11/dist-packages (from mediapy) (11.2.1)
# Requirement already satisfied: setuptools>=18.5 in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (75.2.0)
# Collecting jedi>=0.16 (from ipython->mediapy)
#   Downloading jedi-0.19.2-py2.py3-none-any.whl.metadata (22 kB)
# Requirement already satisfied: decorator in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (4.4.2)
# Requirement already satisfied: pickleshare in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (0.7.5)
# Requirement already satisfied: traitlets>=4.2 in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (5.7.1)
# Requirement already satisfied: prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0 in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (3.0.51)
# Requirement already satisfied: pygments in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (2.19.1)
# Requirement already satisfied: backcall in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (0.2.0)
# Requirement already satisfied: matplotlib-inline in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (0.1.7)
# Requirement already satisfied: pexpect>4.3 in /usr/local/lib/python3.11/dist-packages (from ipython->mediapy) (4.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (1.3.2)
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (4.58.1)
# Requirement already satisfied: kiwisolver>=1.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (1.4.8)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (24.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (3.2.3)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.11/dist-packages (from matplotlib->mediapy) (2.9.0.post0)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /usr/local/lib/python3.11/dist-packages (from jedi>=0.16->ipython->mediapy) (0.8.4)
# Requirement already satisfied: ptyprocess>=0.5 in /usr/local/lib/python3.11/dist-packages (from pexpect>4.3->ipython->mediapy) (0.7.0)
# Requirement already satisfied: wcwidth in /usr/local/lib/python3.11/dist-packages (from prompt-toolkit!=3.0.0,!=3.0.1,<3.1.0,>=2.0.0->ipython->mediapy) (0.2.13)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.7->matplotlib->mediapy) (1.17.0)
# Downloading swig-4.3.1-py3-none-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 25.7 MB/s eta 0:00:00
# Downloading mediapy-1.2.4-py3-none-any.whl (26 kB)
# Downloading jedi-0.19.2-py2.py3-none-any.whl (1.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.6/1.6 MB 47.7 MB/s eta 0:00:00
# Installing collected packages: swig, jedi, mediapy
# Successfully installed jedi-0.19.2 mediapy-1.2.4 swig-4.3.1
# Collecting mujoco==3.1.4
#   Downloading mujoco-3.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.3/44.3 kB 3.0 MB/s eta 0:00:00
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.4) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.4) (1.12.2)
# Collecting glfw (from mujoco==3.1.4)
#   Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl.metadata (5.4 kB)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.4) (2.0.2)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco==3.1.4) (3.1.9)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.4) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.4) (6.5.2)
# Requirement already satisfied: typing_extensions in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.4) (4.14.0)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco==3.1.4) (3.22.0)
# Downloading mujoco-3.1.4-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.5/5.5 MB 5.2 MB/s eta 0:00:00
# Downloading glfw-2.9.0-py2.py27.py3.py30.py31.py32.py33.py34.py35.py36.py37.py38.p39.p310.p311.p312.p313-none-manylinux_2_28_x86_64.whl (243 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 243.5/243.5 kB 22.6 MB/s eta 0:00:00
# Installing collected packages: glfw, mujoco
# Successfully installed glfw-2.9.0 mujoco-3.1.4
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Collecting torchrl
#   Downloading torchrl-0.8.1-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (41 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.5)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2025.3.2)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchrl) (2.0.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from torchrl) (24.2)
# Requirement already satisfied: cloudpickle in /usr/local/lib/python3.11/dist-packages (from torchrl) (3.1.1)
# Collecting tensordict<0.9.0,>=0.8.3 (from torchrl)
#   Downloading tensordict-0.8.3-cp311-cp311-manylinux_2_28_x86_64.whl.metadata (9.2 kB)
# Requirement already satisfied: importlib_metadata in /usr/local/lib/python3.11/dist-packages (from tensordict<0.9.0,>=0.8.3->torchrl) (8.7.0)
# Requirement already satisfied: orjson in /usr/local/lib/python3.11/dist-packages (from tensordict<0.9.0,>=0.8.3->torchrl) (3.10.18)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: zipp>=3.20 in /usr/local/lib/python3.11/dist-packages (from importlib_metadata->tensordict<0.9.0,>=0.8.3->torchrl) (3.22.0)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 1.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 113.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 86.4 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 44.2 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 2.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.7 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.5 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.1 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 93.0 MB/s eta 0:00:00
# Downloading torchrl-0.8.1-cp311-cp311-manylinux_2_28_x86_64.whl (1.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 64.1 MB/s eta 0:00:00
# Downloading tensordict-0.8.3-cp311-cp311-manylinux_2_28_x86_64.whl (420 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 420.7/420.7 kB 34.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12, tensordict, torchrl
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127 tensordict-0.8.3 torchrl-0.8.1
# Collecting gymnasium==0.28.1 (from gymnasium[box2d,mujoco]==0.28.1)
#   Downloading gymnasium-0.28.1-py3-none-any.whl.metadata (9.2 kB)
# Requirement already satisfied: numpy>=1.21.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->gymnasium[box2d,mujoco]==0.28.1) (2.0.2)
# Collecting jax-jumpy>=1.0.0 (from gymnasium==0.28.1->gymnasium[box2d,mujoco]==0.28.1)
#   Downloading jax_jumpy-1.0.0-py3-none-any.whl.metadata (15 kB)
# Requirement already satisfied: cloudpickle>=1.2.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->gymnasium[box2d,mujoco]==0.28.1) (3.1.1)
# Requirement already satisfied: typing-extensions>=4.3.0 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->gymnasium[box2d,mujoco]==0.28.1) (4.14.0)
# Requirement already satisfied: farama-notifications>=0.0.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium==0.28.1->gymnasium[box2d,mujoco]==0.28.1) (0.0.4)
# Collecting box2d-py==2.3.5 (from gymnasium[box2d,mujoco]==0.28.1)
#   Downloading box2d-py-2.3.5.tar.gz (374 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 374.4/374.4 kB 15.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# Collecting pygame==2.1.3 (from gymnasium[box2d,mujoco]==0.28.1)
#   Downloading pygame-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (9.3 kB)
# Requirement already satisfied: swig==4.* in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d,mujoco]==0.28.1) (4.3.1)
# Requirement already satisfied: mujoco>=2.3.2 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d,mujoco]==0.28.1) (3.1.4)
# Requirement already satisfied: imageio>=2.14.1 in /usr/local/lib/python3.11/dist-packages (from gymnasium[box2d,mujoco]==0.28.1) (2.37.0)
# Requirement already satisfied: pillow>=8.3.2 in /usr/local/lib/python3.11/dist-packages (from imageio>=2.14.1->gymnasium[box2d,mujoco]==0.28.1) (11.2.1)
# Requirement already satisfied: absl-py in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (1.4.0)
# Requirement already satisfied: etils[epath] in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (1.12.2)
# Requirement already satisfied: glfw in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (2.9.0)
# Requirement already satisfied: pyopengl in /usr/local/lib/python3.11/dist-packages (from mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (3.1.9)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (2025.3.2)
# Requirement already satisfied: importlib_resources in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (6.5.2)
# Requirement already satisfied: zipp in /usr/local/lib/python3.11/dist-packages (from etils[epath]->mujoco>=2.3.2->gymnasium[box2d,mujoco]==0.28.1) (3.22.0)
# Downloading gymnasium-0.28.1-py3-none-any.whl (925 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 925.5/925.5 kB 41.4 MB/s eta 0:00:00
# Downloading pygame-2.1.3-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 82.9 MB/s eta 0:00:00
# Downloading jax_jumpy-1.0.0-py3-none-any.whl (20 kB)
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py) ... done
#   Created wheel for box2d-py: filename=box2d_py-2.3.5-cp311-cp311-linux_x86_64.whl size=2379372 sha256=50df8172174601717af99d7e2ac4ce656bb2556f05bd207082770aa43d737925
#   Stored in directory: /root/.cache/pip/wheels/ab/f1/0c/d56f4a2bdd12bae0a0693ec33f2f0daadb5eb9753c78fa5308
# Successfully built box2d-py
# Installing collected packages: box2d-py, pygame, jax-jumpy, gymnasium
#   Attempting uninstall: pygame
#     Found existing installation: pygame 2.6.1
#     Uninstalling pygame-2.6.1:
#       Successfully uninstalled pygame-2.6.1
#   Attempting uninstall: gymnasium
#     Found existing installation: gymnasium 1.1.1
#     Uninstalling gymnasium-1.1.1:
#       Successfully uninstalled gymnasium-1.1.1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# dopamine-rl 4.1.2 requires gymnasium>=1.0.0, but you have gymnasium 0.28.1 which is incompatible.
# Successfully installed box2d-py-2.3.5 gymnasium-0.28.1 jax-jumpy-1.0.0 pygame-2.1.3

# %% [markdown]
# # Imports and Functions

# %%
# Imports
import gymnasium as gym
import numpy as np
import matplotlib.pyplot as plt
from matplotlib import animation, rc
from ipywidgets import interact, widgets
# Change to glfw when on Mac. This might fuck up the lighting.
# %env MUJOCO_GL=egl
import mujoco
import mujoco.viewer
import mediapy as media
from time import time

import torch
from torch import nn
import torch.nn.functional as F
from tensordict import TensorDict
from torchrl.data import CompositeSpec, BoundedTensorSpec, UnboundedContinuousTensorSpec
from torchrl.envs.model_based import ModelBasedEnvBase
from torchrl.modules import SafeModule
from torchrl.modules import CEMPlanner
from torchrl.modules import WorldModelWrapper
from torchrl.data import TensorDictReplayBuffer
# Out:
# env: MUJOCO_GL=egl
# /usr/local/lib/python3.11/dist-packages/torchrl/data/replay_buffers/samplers.py:34: UserWarning: Failed to import torchrl C++ binaries. Some modules (eg, prioritized replay buffers) may not work with your installation. This is likely due to a discrepancy between your package version and the PyTorch version. Make sure both are compatible. Usually, torchrl majors follow the pytorch majors within a few days around the release. For instance, TorchRL 0.5 requires PyTorch 2.4.0, and TorchRL 0.6 requires PyTorch 2.5.0.
#   warnings.warn(EXTENSION_WARNING)

# %%
#render_episode: Evaluates and visualizes a policy’s performance, critical for debugging and showcasing results.
def render_episode(policy, env, max_steps=1000):
	frames = []
	score = 0
	state = env.get_state()
	terminated = truncated = False
	while not terminated and not truncated and len(frames)<max_steps:
		frame = env.render()
		frames.append(frame)
		action = policy(state)
		state, reward, terminated, truncated, _ = env.step(action)
		score += reward
	env.close()
	print(f"Finished episode. Cummulative Return: {score}")
	media.show_video(frames, fps=50, loop=True)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# MujocoCartPoleEnv: Defines the environment’s dynamics, state/action spaces, and reward structure, serving as the ground truth for simulation and training.
class MujocoCartPoleEnv(gym.Env):
    def __init__(self, m = 2, M = 5, l = 0.5, g = 9.81, k = 100, dt = 0.02, end_on_failure = True):
        self.model = self._get_mj_model(m,M,l,g,k,dt)
        self.data = mujoco.MjData(self.model)
        self.renderer = mujoco.Renderer(self.model)
        self.truncate = 1000
        self.action_space = gym.spaces.Box(low=-1, high=1, shape=(self.model.nu,))
        self.observation_space = gym.spaces.Box(low=-np.inf, high=np.inf, shape=(self.model.nq + self.model.nv,))
        self.end_on_failure = end_on_failure
        self.reset()

    def reset(self):
        mujoco.mj_resetData(self.model, self.data)
        self.data.qvel = 0.0*np.random.randn(2) # velocities
        self.data.qpos = 0.1*np.random.randn(2) # positions
        self.timestep = 0
        return self.get_state(), {}

    def set_state(self, state):
        self.data.qpos = state[:self.model.nq]
        self.data.qvel = state[self.model.nq:]

    def get_state(self):
        return np.concatenate([self.data.qpos, self.data.qvel])

    def step(self, action):
        self.data.ctrl = action
        mujoco.mj_step(self.model, self.data)
        next_state = self.get_state()
        reward = self._calculate_reward()
        terminal = self._is_done()
        truncated = self.timestep >= self.truncate
        info = {}  # Additional information (optional)
        self.timestep += 1
        return (next_state, reward, terminal, truncated, info)
        # next_state: The state after the step.
        # reward: The reward based on the pole angle.
        # terminal: Whether the episode has ended due to failure.
        # truncated: Whether the episode has reached the maximum steps.
        # info: An empty dictionary.


    def render(self):
        self.renderer.update_scene(self.data)
        return self.renderer.render()

    def _calculate_reward(self):
        # Calculate reward based on the current state (optional)
        return int(self.data.qpos[1] > - np.pi/12 and self.data.qpos[1] < np.pi/6)

    def _is_done(self):
        # Check if the episode is done based on the current state (optional)
        if self.end_on_failure:
            return (self.data.qpos[1] < - np.pi/12 or self.data.qpos[1] > np.pi/6)
        return False

    # return a mujoco model with the given physical parameters
    @staticmethod
    def _get_mj_model(m,M,l,g,k,dt):
        xml = f"""
        <mujoco model='test_cartpole'>
            <compiler inertiafromgeom='true' coordinate='local'/>

            <size nkey="1"/>

            <option timestep='{dt}' integrator="RK4" gravity='0 0 {-g}'/>

            <default>
            <joint damping='0.0' solreflimit='.08 1'/>
            <geom contype='0' friction='0. 0. 0.'/>
            </default>

            <worldbody>
            <camera name='fixed' pos='0 -2.5 0' quat='0.707 0.707 0 0'/>
            <light name="top" castshadow="false"/>
            <geom name='floor' pos='0 0 -1' size='4 4 4' type='plane' />
            <geom name='rail1' type='capsule' pos='0 .07 0' quat='0.707 0 0.707 0'
                    size='0.02 2.2' />
            <geom name='rail2' type='capsule' pos='0 -.07 0' quat='0.707 0 0.707 0'
                    size='0.02 2.2' />
            <body name='cart' pos='0 0 0'>
                <camera name='cart' pos='0 -2.5 0' quat='0.707 0.707 0 0' />
                <joint name='slider' type='slide' limited='true' pos='0 0 0'
                        axis='1 0 0' range='-2 2' />
                <geom name='cart' type='box' pos='0 0 0'
                        mass='{M}' size='0.2 0.1 0.05' rgba='0.7 0.7 0 1' />
                <site name='cart sensor' type='box' pos='0 0 0'
                        size='0.2 0.1 0.05' rgba='0.7 0.7 0 0' />
                <body name='pole' pos='0 0 0'>
                <camera name='pole'  pos='0 -2.5 0' quat='0.707 0.707 0 0' />
                <joint name='hinge' type='hinge' pos='0 0 0' axis='0 1 0'/>
                <geom name='cpole' type='capsule' fromto='0 0 0 0 0 {l}'
                        mass='0' size='0.01 {l}' rgba='0 0.7 0.7 1' />
                <geom type='sphere' size='.05' name='tip' mass='{m}' pos='.001 0 {l}'/>
                </body>
            </body>
            </worldbody>

            <actuator>
            <motor name='slide' joint='slider' gear='{k}' ctrllimited='true' ctrlrange='-1 1' />
            </actuator>

        </mujoco>
        """
        return mujoco.MjModel.from_xml_string(xml)

# %% [markdown]
# # Model-Based Reinforcement Learning
# Model-based reinforcement learning (MBRL) is a powerful approach that combines the principles of reinforcement learning with the use of predictive models. In MBRL, an agent learns a model of the environment dynamics and uses this model to plan and make decisions. By explicitly representing the dynamics of the environment, MBRL enables the agent to simulate different scenarios and evaluate the potential outcomes of different actions. This allows the agent to make more informed decisions and optimize its behavior in complex and uncertain environments. In contrast to model-free reinforcement learning, which learns directly from trial and error, MBRL leverages the learned model to plan ahead and make more efficient use of the available data. Also, the learned model is task-agnostic, so that an MBRL agent does not have to learn from scratch for new tasks. However, MBRL also comes with its own set of challenges. Building an accurate model of the environment can be difficult, and errors in the model can lead to suboptimal performance. Additionally, the planning process in MBRL can be computationally expensive, especially in large and complex environments. Despite these challenges, MBRL offers the potential for improved sample efficiency and better performance in certain domains.

# %%
# Objective function
# quadratic_cost: Guides the planning process by quantifying the quality of state trajectories, enabling optimization of actions.
def quadratic_cost(trajectory, desired_state = torch.zeros(4), weight = torch.tensor([1.,2.,0.,0.])): # Weights for each state component (default: [1., 2., 0., 0.], prioritizing cart position and pole angle).
	with torch.no_grad():
		return torch.square(trajectory-desired_state)@weight

# Wrapper for the world model
# MyTorchRLModel: Integrates the environment with TorchRL, providing a framework for model-based planning by specifying state, action, and reward structures.
class MyTorchRLModel(ModelBasedEnvBase):
    def __init__(self, world_model, device="cpu", batch_size=None):
        super().__init__(world_model, device=device, batch_size=batch_size)
        self.state_spec = CompositeSpec(
            state=UnboundedContinuousTensorSpec((4,))
        )
        self.observation_spec = CompositeSpec(
            state=UnboundedContinuousTensorSpec((4,))
        )
        self.action_spec = BoundedTensorSpec(-1,1,(1,))
        self.reward_spec = UnboundedContinuousTensorSpec((1,))

    def _reset(self, tensordict: TensorDict) -> TensorDict:
        tensordict = TensorDict(
            source={'state': torch.tensor([0.,0.,0.,0.]),
                    'action': torch.tensor([0.])},
            batch_size=self.batch_size,
            device=self.device,
        )
        return tensordict

# %% [markdown]
# ## Learning the forward model
# Learning a forward dynamics model using supervised learning involves training a model to predict the future state of a system given its current state and the applied control inputs. In this approach, a dataset is collected by executing the system under different control inputs and recording the corresponding state transitions. The dataset is then used to train a supervised learning model, such as a neural network, to learn the underlying dynamics of the system. The model is trained to minimize the prediction error between the predicted future state and the actual future state. Once trained, the forward dynamics model can be used to simulate the behavior of the system and make predictions about its future states under different control inputs. This approach is particularly useful in model-based reinforcement learning, where the learned forward dynamics model can be used for planning and decision-making purposes.

# %%
## Main
# Neural Network as forward dynamics and reward model
## class ForwardDynamicsModel(nn.Module):
    #### Your code here ####

## Solution
# Neural Network as forward dynamics and reward model
class ForwardDynamicsModel(nn.Module):
    def __init__(self, state_dim, action_dim, hidden_dim = 256):
      # state_dim: Dimension of the state space (e.g., 4 for CartPole: position, angle, velocity, angular velocity).
      # action_dim: Dimension of the action space (e.g., 1 for the cart's control input).
      # hidden_dim: Number of neurons in the hidden layer (default: 256).
        super(ForwardDynamicsModel, self).__init__()
        self.fc1 = nn.Linear(state_dim+action_dim, hidden_dim)  # A linear layer (fc1) from state_dim + action_dim to hidden_dim.
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(hidden_dim, state_dim)

    def forward(self, state, action):  # Concatenates state and action along the feature dimension.
        x = torch.cat((state, action), dim=1)
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x) + state
        return x

# Role in MBRL: Learns to approximate the environment's dynamics, enabling simulation and planning.

# %%
## Solution
# we define an agent that can act and learn
class MBRLAgent():
    def __init__(self, state_size, action_size, seed = 42, device = 'cpu'): # seed: Random seed for reproducibility (default: 42).
        self.state_size = state_size
        self.action_size = action_size
        self.batch_size = 64
        self.device = device
        self.replay_buffer = TensorDictReplayBuffer(batch_size=self.batch_size)  # replay_buffer: Stores state transitions for training.
        self.model = ForwardDynamicsModel(state_size, action_size) # Instance of ForwardDynamicsModel.
        world_model = WorldModelWrapper(  # world_model: Wraps the dynamics and reward models using WorldModelWrapper.
            SafeModule(
                self.model,
                in_keys=["state", "action"],
                out_keys=["state"],
            ),
            SafeModule(
                lambda traj: - quadratic_cost(traj),
                in_keys=["state"],
                out_keys=["reward"],
            ),
        )
        plan_model = MyTorchRLModel(world_model, device=device)
        self.planner = CEMPlanner(plan_model, 20, 4, 1000, 3)  # planner: Uses CEMPlanner for action optimization over 20 iterations, 4 samples per iteration, 1000 horizon, and 3 elite samples.
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=0.0001)
        self.init_period = 500  # init_period: Initial random exploration period (500 steps).
        self.update_every = 4  # update_every: Frequency of model updates (every 4 steps).
        self.update_steps = 16  # update_steps: Number of optimization steps per update (16).
        self.t_step = 0  # t_step: Tracks the number of time steps.

    def step(self, state, action, reward, next_state, done):
        self.replay_buffer.add(
            TensorDict({
                'state': torch.from_numpy(state),
                'action': torch.from_numpy(action),
                'next_state': torch.from_numpy(next_state)
                }
            ),
        )
        # Learn every update_every time steps.
        if self.t_step % self.update_every == 0:
            if self.t_step > self.init_period:
                for _ in range(self.update_steps):
                    self.learn()
        self.t_step += 1

    def act(self, state, eps=0.):
        self.model.eval()
        if self.t_step < self.init_period:  # If t_step < init_period, returns a random action.
            return np.random.uniform(-1, 1, (1,)).astype(np.float32)
        td = TensorDict({'action': torch.tensor([0.]),
					 'done': torch.tensor([False]),
					 'state': torch.tensor(state, dtype=torch.float32).to(self.device),
					 'terminated': torch.tensor([False])})
        return self.planner(td)['action'].detach().numpy()  # Otherwise, uses the planner to select an action based on the current state.

    def learn(self):
        self.model.train()
        td = self.replay_buffer.sample(self.batch_size) # Trains the model by sampling a batch from the replay buffer.
        next_state_predcited = self.model(td['state'], td['action'])
        loss = F.mse_loss(next_state_predcited, td['next_state']) # Computes the mean squared error loss between predicted and actual next states.
        self.optimizer.zero_grad()
        loss.backward()  # Updates the model parameters via backpropagation.
        self.optimizer.step()

# Role in MBRL: Combines model learning, planning, and interaction with the environment to optimize performance.

# %%
## Main
# we define an agent that can act and learn
class MBRLAgent():
    def __init__(self, state_size, action_size, seed = 42, device = 'cpu'):
        self.state_size = state_size
        self.action_size = action_size
        self.batch_size = 64
        self.device = device
        self.replay_buffer = TensorDictReplayBuffer(batch_size=self.batch_size)
        self.model = ForwardDynamicsModel(state_size, action_size)
        world_model = WorldModelWrapper(
            SafeModule(
                self.model,
                in_keys=["state", "action"],
                out_keys=["state"],
            ),
            SafeModule(
                lambda traj: - quadratic_cost(traj),
                in_keys=["state"],
                out_keys=["reward"],
            ),
        )
        plan_model = MyTorchRLModel(world_model, device=device)
        self.planner = CEMPlanner(plan_model, 20, 4, 1000, 3)
        self.optimizer = torch.optim.Adam(self.model.parameters(), lr=0.0001)
        self.init_period = 1000
        self.update_every = 4
        self.update_steps = 16
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        self.replay_buffer.add(
            TensorDict({
                'state': torch.from_numpy(state),
                'action': torch.from_numpy(action),
                'next_state': torch.from_numpy(next_state)
                }
            ),
        )
        # Learn every update_every time steps.
        if self.t_step % self.update_every == 0:
            if self.t_step > self.init_period:
                for _ in range(self.update_steps):
                    self.learn()
        self.t_step += 1

    def act(self, state, eps=0.):
        self.model.eval()
        if self.t_step < self.init_period:
            return np.random.uniform(-1, 1, (1,)).astype(np.float32)
        td = TensorDict({'action': torch.tensor([0.]),
					 'done': torch.tensor([False]),
					 'state': torch.tensor(state, dtype=torch.float32).to(self.device),
					 'terminated': torch.tensor([False])})
        return self.planner(td)['action'].detach().numpy()

    def learn(self):
       ### Your code here ###

# %%
# Training Loop
agent = MBRLAgent(4, 1)
env = MujocoCartPoleEnv(end_on_failure=True)
scores = []
for i in range(100): # Runs 100 episodes or stops early if the average score of the last 5 episodes exceeds 700.
    state,_ = env.reset()
    score = 0
    done = False
    while not done:
        action = agent.act(state)
        next_state, reward, terminal, truncated, _ = env.step(action)  # Resets the environment and initializes the score.
        done = terminal or truncated  # Runs until termination or truncation.
        agent.step(state.astype(np.float32), action.astype(np.float32), reward, next_state.astype(np.float32), done)
        # Selects actions with agent.act, steps the environment, updates the agent with agent.step, and accumulates the reward.
        state = next_state
        score += reward
    print(f"Episode {i}, Score: {score}")  # Prints and stores the episode score.
    scores.append(score)
    if len(scores)>5 and np.mean(scores[-5:]) >= 700:
        break

# Role in MBRL: Drives the learning process, collecting data and evaluating the agent’s performance.
# Out:
# /usr/local/lib/python3.11/dist-packages/torchrl/data/tensor_specs.py:6705: DeprecationWarning: The UnboundedContinuousTensorSpec has been deprecated and will be removed in v0.8. Please use Unbounded instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchrl/data/tensor_specs.py:6705: DeprecationWarning: The CompositeSpec has been deprecated and will be removed in v0.8. Please use Composite instead.
#   warnings.warn(
# /usr/local/lib/python3.11/dist-packages/torchrl/data/tensor_specs.py:6705: DeprecationWarning: The BoundedTensorSpec has been deprecated and will be removed in v0.8. Please use Bounded instead.
#   warnings.warn(
# Episode 0, Score: 26
# Episode 1, Score: 28
# Episode 2, Score: 25
# Episode 3, Score: 24
# Episode 4, Score: 30
# Episode 5, Score: 14
# Episode 6, Score: 19
# Episode 7, Score: 14
# Episode 8, Score: 16
# Episode 9, Score: 27
# Episode 10, Score: 21
# Episode 11, Score: 17
# Episode 12, Score: 17
# Episode 13, Score: 25
# Episode 14, Score: 15
# Episode 15, Score: 13
# Episode 16, Score: 6
# Episode 17, Score: 36
# Episode 18, Score: 36
# Episode 19, Score: 10
# Episode 20, Score: 16
# Episode 21, Score: 28
# Episode 22, Score: 8
# Episode 23, Score: 16
# Episode 24, Score: 28
# Episode 25, Score: 24
# Episode 26, Score: 34
# Episode 27, Score: 89
# Episode 28, Score: 174
# Episode 29, Score: 55
# Episode 30, Score: 331
# Episode 31, Score: 568
# Episode 32, Score: 134
# Episode 33, Score: 1001
# Episode 34, Score: 164
# Episode 35, Score: 156
# Episode 36, Score: 1001
# Episode 37, Score: 229
# Episode 38, Score: 1001
# Episode 39, Score: 1001
# Episode 40, Score: 1001

# %%
# Purpose: Visualizes the episode length (a proxy for performance) over episodes, highlighting the transition from random exploration to learning.
# X-axis: Episode number (0 to 40).
# Y-axis: Episode length (0 to 1000), representing the number of steps before termination or truncation.
fig, ax = plt.subplots()
start_learning = np.where(np.cumsum(scores) > agent.init_period)[0][0]
ax.plot(scores, label='Episode Length')
ax.axvline(start_learning, color='r', linestyle='--', label='Start Learning')
ax.set_xlabel('Episode')
ax.set_ylabel('Episode Length')
fig.legend()

# Blue Line (Episode Length): Plots the length of each episode. Initially near 0 (due to early termination from random actions), it increases sharply after learning begins, indicating improved control.
# Red Dashed Line (Start Learning): A vertical line at the episode where the cumulative score exceeds the init_period (500 steps), marking the start of model-based learning (around episode 25).

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
env = MujocoCartPoleEnv(end_on_failure=True)
env.reset()
render_episode(agent.act, env) # Render an episode
# Out:
# Finished episode. Cummulative Return: 1000
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# ### Tasks:
# 1. Implement the forward model as a neural network.
# 2. Implement the learn function of the MBRL agent. You can choose a loss function. An easy choice would be the MSE of the
# 3. Compare the performance of Model-Based RL and Model-Free RL agents (DQN, REINFORCE, AC,... are Model-Free) in terms of wall-clock time and data-efficiency.
# 4. What issues do you see when training a forward model with an MSE loss function for optimizing rewards?

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **or Ans:**
# - **Wall-clock time:**
#  Model-Free RL often requires less computation per step but needs many
#  environment interactions, leading to long training times overall. Model-Based RL can
#  be slower per step (due to planning) but may converge faster.
# - **Data-efficiency:**
#  Model-Based RL is generally more data-efficient, as it learns from simulated rollouts
#  using the model. Model-Free methods typically need much more experience to learn effective policies.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **or Ans:**
#  Using MSE to train a forward model in model-based RL may lead to a
#  fundamental mismatch between the model's training objective and the RL goal (i.e.,
#  maximizing rewards

# %% [markdown]
# # Policy Distillation
# Policy distillation is a technique in reinforcement learning that aims to transfer knowledge from a high-performing "teacher" policy to a "student" policy. The teacher policy is typically a complex and well-trained policy that has achieved good performance in a given task. The goal of policy distillation is to distill the knowledge and expertise of the teacher policy into a simpler and more computationally efficient student policy. This is done by training the student policy to mimic the behavior of the teacher policy, either by directly imitating its actions or by learning from its policy logits. Policy distillation can be particularly useful in scenarios where the teacher policy is too computationally expensive to deploy in real-time or when the teacher policy's knowledge needs to be transferred to a resource-constrained environment. By distilling the teacher policy's knowledge into a student policy, we can achieve comparable performance with reduced computational requirements, making it a valuable technique in reinforcement learning.

# %%
# Neural Network Policy
class DeterministicPolicy(nn.Module):
    def __init__(self, obs_space_dims: int, action_space_dims: int, hidden_space:int=64):
        super().__init__()
        self.net = nn.Sequential(
            nn.Linear(obs_space_dims, hidden_space),
            nn.ELU(),
            nn.Linear(hidden_space, action_space_dims),
        )

    def forward(self, x: torch.Tensor):
        return self.net(x)

# %%
# Distill the agents policy into a neural network policy
def distill_policy(agent, policy, batches=30, updates_per_batch=40):

    optim = torch.optim.Adam(policy.parameters(), lr=0.05)
    policy.train()
    for i in range(batches):
        batch = agent.replay_buffer.sample(agent.batch_size)
        states = batch['state']
        mbrl_actions = torch.stack([torch.from_numpy(agent.act(state)) for state in states])
        for j in range(updates_per_batch):
            policy_actions = policy(states)
            loss = F.mse_loss(policy_actions, mbrl_actions)
            optim.zero_grad()
            loss.backward()
            optim.step()
        print(f"Batch {i} - Loss: {loss.item():.2f}")

# %%
# create and distill nn policy
policy = DeterministicPolicy(4, 1)
distill_policy(agent,policy)
# Out:
# <ipython-input-7-3338018394>:53: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.clone().detach() or sourceTensor.clone().detach().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   'state': torch.tensor(state, dtype=torch.float32).to(self.device),
# Batch 0 - Loss: 0.14
# Batch 1 - Loss: 0.14
# Batch 2 - Loss: 0.12
# Batch 3 - Loss: 0.16
# Batch 4 - Loss: 0.09
# Batch 5 - Loss: 0.11
# Batch 6 - Loss: 0.13
# Batch 7 - Loss: 0.12
# Batch 8 - Loss: 0.12
# Batch 9 - Loss: 0.13
# Batch 10 - Loss: 0.13
# Batch 11 - Loss: 0.09
# Batch 12 - Loss: 0.11
# Batch 13 - Loss: 0.14
# Batch 14 - Loss: 0.08
# Batch 15 - Loss: 0.16
# Batch 16 - Loss: 0.13
# Batch 17 - Loss: 0.11
# Batch 18 - Loss: 0.13
# Batch 19 - Loss: 0.14
# Batch 20 - Loss: 0.10
# Batch 21 - Loss: 0.11
# Batch 22 - Loss: 0.06
# Batch 23 - Loss: 0.12
# Batch 24 - Loss: 0.13
# Batch 25 - Loss: 0.10
# Batch 26 - Loss: 0.13
# Batch 27 - Loss: 0.09
# Batch 28 - Loss: 0.15
# Batch 29 - Loss: 0.12

# %%
# Run the distilled policy
env = MujocoCartPoleEnv(end_on_failure=True)
env.reset()
policy.eval()
render_episode(lambda s: policy(torch.from_numpy(s.astype(np.float32))).detach().cpu().numpy(), env) # Render an episode
# Out:
# Finished episode. Cummulative Return: 1000
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %% [markdown]
# ### Tasks
# 1. Compare the inference time for the CEM planner and the NN policy.
# 2. We have seen that model-based RL algorithms are a lot more data efficient than model-free ones. However, model-free algorithms are computationally a lot more efficient. Can you think of a good combination of the two approaches? Code an agent that simultaneously learns a forward model and a policy (and maybe even a value function). Try to let it converge to a score of 1000 in no more than 100 episodes while having an inference time of no more than 50 ms. You can use the quadratic cost function.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# **or Ans:** The NN policy has much faster inference time than the CEM planner, as it requires
#  only a single forward pass, while CEM performs many rollouts and optimizations.

# %% [markdown]
# **Task 2:** Combine Model-Based and Model-Free RL
# - Approach: Create a hybrid agent that learns a forward model (for data efficiency) and a policy (for fast inference), using DQN-style Q-learning for the policy and the forward model for planning.
# - Add a value function to guide learning.
# -  The agent uses the forward model to simulate rollouts, improving data efficiency, while the policy trains directly on rewards, reducing inference time.

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
## Solution
# we define an agent that can act and learn
class PolicyPlanningAgent():
    def __init__(self, state_size, action_size, seed = 42, device = 'cpu'):
        self.state_size = state_size
        self.action_size = action_size
        self.batch_size = 64
        self.device = device
        self.replay_buffer = TensorDictReplayBuffer(batch_size=self.batch_size)
        self.model = ForwardDynamicsModel(state_size, action_size)
        self.policy = DeterministicPolicy(state_size, action_size)
        self.model_optimizer = torch.optim.Adam(self.model.parameters(), lr=0.0001)
        self.policy_optimizer = torch.optim.Adam(self.policy.parameters(), lr=0.05)
        self.update_model_every = 4
        self.update_model_steps = 16
        self.update_policy_every = 256
        self.update_policy_steps = 32
        self.init_period = 500
        self.t_step = 0

    def step(self, state, action, reward, next_state, done):
        self.replay_buffer.add(
            TensorDict({
                'state': torch.from_numpy(state),
                'action': torch.from_numpy(action),
                'next_state': torch.from_numpy(next_state)
                }
            ),
        )
        # Learn every update_every time steps.
        if self.t_step > self.init_period:
            self.learn()
        self.t_step += 1

    def _quadratic_cost(self, trajectory, desired_state = torch.zeros(4), weight = torch.tensor([1.,10.,0.,0.])):
        with torch.no_grad():
            return torch.sum(torch.square(trajectory-desired_state)@weight,dim=1)

    def plan(self, state, horizon = 20, num_candidates=5000, eps=0.2):
        states = torch.tile(state, (num_candidates,1))
        trajectory = torch.zeros((num_candidates, horizon, self.state_size))
        first_actions = torch.rand((num_candidates, self.action_size))*2-1
        actions = first_actions
        for t in range(horizon):
            states = self.model(states, actions)
            trajectory[:,t,:] = states
            noise = torch.randn((num_candidates, self.action_size))*eps
            actions = self.policy(states) + noise
        costs = self._quadratic_cost(trajectory)
        best_cand = costs.argmin()
        return first_actions[best_cand]

    def act(self, state, eps=0.):
        self.model.eval()
        self.policy.eval()
        action = self.plan(torch.from_numpy(state.astype(np.float32))).detach().numpy()
        # noise = np.random.randn()*eps
        return np.clip(action,-1,1)

    def learn(self):
        # forward model
        if self.t_step % self.update_model_every == 0:
            self.model.train()
            for _ in range(self.update_model_steps):
                batch = self.replay_buffer.sample(self.batch_size)
                next_state_predcited = self.model(batch['state'], batch['action'])
                loss = F.mse_loss(next_state_predcited, batch['next_state'])
                self.model_optimizer.zero_grad()
                loss.backward()
                self.model_optimizer.step()

        # policy
        if self.t_step % self.update_policy_every == 0:
            self.policy.train()
            batch = self.replay_buffer[-self.update_policy_every:]
            for _ in range(self.update_policy_steps):
                policy_actions = self.policy(batch['state'])
                loss = F.mse_loss(policy_actions, batch['action'])
                self.policy_optimizer.zero_grad()
                loss.backward()
                self.policy_optimizer.step()

# %%
# Training Loop
agent = PolicyPlanningAgent(4, 1)
env = MujocoCartPoleEnv(end_on_failure=True)
scores = []
for i in range(100):
    inference_time = 0.
    state,_ = env.reset()
    score = 0
    done = False
    t = 0
    while not done:
        t1 = time()
        action = agent.act(state)
        inference_time += time()-t1
        next_state, reward, terminal, truncated, _ = env.step(action)
        done = terminal or truncated
        agent.step(state.astype(np.float32), action.astype(np.float32), reward, next_state.astype(np.float32), done)
        state = next_state
        score += reward
        t += 1
    print(f"Episode {i}, Score: {score}, avg. inference time: {1000.*inference_time/t:.2f}ms")
    scores.append(score)
    if len(scores)>5 and np.mean(scores[-5:]) >= 700:
        break
# Out:
# Episode 0, Score: 8, avg. inference time: 130.24ms
# Episode 1, Score: 7, avg. inference time: 119.20ms
# Episode 2, Score: 10, avg. inference time: 119.60ms
# Episode 3, Score: 6, avg. inference time: 104.22ms
# Episode 4, Score: 5, avg. inference time: 106.43ms
# Episode 5, Score: 11, avg. inference time: 104.64ms
# Episode 6, Score: 6, avg. inference time: 105.83ms
# Episode 7, Score: 10, avg. inference time: 105.54ms
# Episode 8, Score: 11, avg. inference time: 105.02ms
# Episode 9, Score: 7, avg. inference time: 103.18ms
# Episode 10, Score: 8, avg. inference time: 103.91ms
# Episode 11, Score: 11, avg. inference time: 102.29ms
# Episode 12, Score: 3, avg. inference time: 99.29ms
# Episode 13, Score: 10, avg. inference time: 115.02ms
# Episode 14, Score: 9, avg. inference time: 118.20ms
# Episode 15, Score: 7, avg. inference time: 119.67ms
# Episode 16, Score: 14, avg. inference time: 121.65ms
# Episode 17, Score: 11, avg. inference time: 95.60ms
# Episode 18, Score: 8, avg. inference time: 93.46ms
# Episode 19, Score: 7, avg. inference time: 93.11ms
# Episode 20, Score: 7, avg. inference time: 93.50ms
# Episode 21, Score: 12, avg. inference time: 91.57ms
# Episode 22, Score: 7, avg. inference time: 91.20ms
# Episode 23, Score: 10, avg. inference time: 91.13ms
# Episode 24, Score: 8, avg. inference time: 92.89ms
# Episode 25, Score: 9, avg. inference time: 96.89ms
# Episode 26, Score: 7, avg. inference time: 112.78ms
# Episode 27, Score: 5, avg. inference time: 110.29ms
# Episode 28, Score: 12, avg. inference time: 112.52ms
# Episode 29, Score: 8, avg. inference time: 92.27ms
# Episode 30, Score: 4, avg. inference time: 89.94ms
# Episode 31, Score: 3, avg. inference time: 98.32ms
# Episode 32, Score: 6, avg. inference time: 92.63ms
# Episode 33, Score: 5, avg. inference time: 92.34ms
# Episode 34, Score: 9, avg. inference time: 92.07ms
# Episode 35, Score: 8, avg. inference time: 90.91ms
# Episode 36, Score: 5, avg. inference time: 94.58ms
# Episode 37, Score: 11, avg. inference time: 91.25ms
# Episode 38, Score: 8, avg. inference time: 92.51ms
# Episode 39, Score: 9, avg. inference time: 93.06ms
# Episode 40, Score: 7, avg. inference time: 94.35ms
# Episode 41, Score: 10, avg. inference time: 97.64ms
# Episode 42, Score: 7, avg. inference time: 114.23ms
# Episode 43, Score: 8, avg. inference time: 112.43ms
# Episode 44, Score: 10, avg. inference time: 109.67ms
# Episode 45, Score: 8, avg. inference time: 92.63ms
# Episode 46, Score: 12, avg. inference time: 94.84ms
# Episode 47, Score: 9, avg. inference time: 115.67ms
# Episode 48, Score: 6, avg. inference time: 126.81ms
# Episode 49, Score: 9, avg. inference time: 92.92ms
# Episode 50, Score: 5, avg. inference time: 96.48ms
# Episode 51, Score: 11, avg. inference time: 94.82ms
# Episode 52, Score: 9, avg. inference time: 94.28ms
# Episode 53, Score: 9, avg. inference time: 94.82ms
# Episode 54, Score: 10, avg. inference time: 98.19ms
# Episode 55, Score: 10, avg. inference time: 112.28ms
# Episode 56, Score: 8, avg. inference time: 117.75ms
# Episode 57, Score: 8, avg. inference time: 94.68ms
# Episode 58, Score: 10, avg. inference time: 95.10ms
# Episode 59, Score: 5, avg. inference time: 95.54ms
# Episode 60, Score: 7, avg. inference time: 96.56ms
# Episode 61, Score: 5, avg. inference time: 93.23ms
# Episode 62, Score: 86, avg. inference time: 100.54ms
# Episode 63, Score: 40, avg. inference time: 102.22ms
# Episode 64, Score: 27, avg. inference time: 94.93ms
# Episode 65, Score: 25, avg. inference time: 97.26ms
# Episode 66, Score: 22, avg. inference time: 121.29ms
# Episode 67, Score: 36, avg. inference time: 87.47ms
# Episode 68, Score: 22, avg. inference time: 87.69ms
# Episode 69, Score: 30, avg. inference time: 90.66ms
# Episode 70, Score: 17, avg. inference time: 109.37ms
# Episode 71, Score: 72, avg. inference time: 86.53ms
# Episode 72, Score: 20, avg. inference time: 86.05ms
# Episode 73, Score: 66, avg. inference time: 93.42ms
# Episode 74, Score: 53, avg. inference time: 83.89ms
# Episode 75, Score: 115, avg. inference time: 89.17ms
# Episode 76, Score: 12, avg. inference time: 83.41ms
# Episode 77, Score: 67, avg. inference time: 93.35ms
# Episode 78, Score: 56, avg. inference time: 101.35ms
# Episode 79, Score: 69, avg. inference time: 108.31ms
# Episode 80, Score: 98, avg. inference time: 91.13ms
# Episode 81, Score: 66, avg. inference time: 98.14ms
# Episode 82, Score: 83, avg. inference time: 97.93ms
# Episode 83, Score: 132, avg. inference time: 91.70ms
# Episode 84, Score: 137, avg. inference time: 98.28ms
# Episode 85, Score: 135, avg. inference time: 112.21ms
# Episode 86, Score: 272, avg. inference time: 99.29ms
# Episode 87, Score: 358, avg. inference time: 90.66ms
# Episode 88, Score: 40, avg. inference time: 87.07ms
# Episode 89, Score: 1001, avg. inference time: 98.76ms
# Episode 90, Score: 215, avg. inference time: 103.26ms
# Episode 91, Score: 60, avg. inference time: 91.29ms
# Episode 92, Score: 30, avg. inference time: 88.71ms
# Episode 93, Score: 699, avg. inference time: 95.50ms
# Episode 94, Score: 72, avg. inference time: 95.61ms
# Episode 95, Score: 950, avg. inference time: 102.35ms
# Episode 96, Score: 1001, avg. inference time: 100.56ms
# Episode 97, Score: 495, avg. inference time: 96.49ms
# Episode 98, Score: 395, avg. inference time: 92.66ms
# Episode 99, Score: 857, avg. inference time: 94.80ms

# %%
# Plot results
fig, ax = plt.subplots()
start_learning = np.where(np.cumsum(scores) > agent.init_period)[0][0]
ax.plot(scores, label='Episode Length')
ax.axvline(start_learning, color='r', linestyle='--', label='Start Learning')
ax.set_xlabel('Episode')
ax.set_ylabel('Episode Length')
fig.legend()

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
# Render episode using the planner
env = MujocoCartPoleEnv(end_on_failure=True)
env.reset()
render_episode(agent.act, env) # Render an episode
# Out:
# Finished episode. Cummulative Return: 1000
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>

# %%
# Render episode using the policy
env = MujocoCartPoleEnv(end_on_failure=True)
env.reset()
agent.policy.eval()
render_episode(lambda s: agent.policy(torch.from_numpy(s.astype(np.float32))).detach().cpu().numpy(), env) # Render an episode
# Out:
# Finished episode. Cummulative Return: 1000
# <table class="show_videos" style="border-spacing:0px;"><tr><td style="padding:1px;"><video controls width="320" height="240" style="object-fit:cover;" loop autoplay muted>
#       <source src="data:video/mp4;base64,..." type="video/mp4"/>
#       This browser does not support the video tag.
#       </video></td></tr></table>
